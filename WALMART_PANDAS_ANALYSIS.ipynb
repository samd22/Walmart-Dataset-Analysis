# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

# %%
df= pd.read_csv("Cleaned_Walmart_Data.csv")

# %%
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Year  Month  Day
# 0         8.106  2010      5    2
# 1         8.106  2010     12    2
# 2         8.106  2010      2   19
# 3         8.106  2010      2   26
# 4         8.106  2010      5    3

# %% [markdown]
# # Correlation of CPI and Sales

# %%
CPI_vs_Weekly_Sales = sns.scatterplot(x="CPI", y="Weekly_Sales", data=df)
CPI_vs_Weekly_Sales = plt.figure(figsize=(6, 4))
CPI_vs_Weekly_Sales

# %% [markdown]
# Insight: Doesn't seem to be highly correlated but will check with corr() function

# %% [markdown]
# # Find correlation of all vars to Weekly_Sales

# %%
df.corr()['Weekly_Sales'].abs().sort_values(ascending=True)
# Out:
# Fuel_Price      0.009464
# Day             0.014873
# Year            0.018378
# Holiday_Flag    0.036891
# Temperature     0.063810
# Month           0.067535
# CPI             0.072634
# Unemployment    0.106176
# Store           0.335332
# Weekly_Sales    1.000000
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# Insight: It seems that the Store, Unemployment, and CPI influences Weekly_Sales the most.
